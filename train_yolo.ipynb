# %%
# !pwd
# Out:
# /home/alan_khang/dev/YOLOF-MaskV2-mmcv

# %%
from ultralytics import YOLO

# %%
model = YOLO("yolov8s-seg.pt")

results = model.train(
    data='./datasets/bdd100k/labels_yolo/data.yaml',
    epochs=36,
    imgsz=(1333, 800),
    batch=2,
    device=0,
    workers=4,
    name='yolo8s_bdd100k',
    pretrained=False,
    optimizer='AdamW',
    lr0=1e-4,
    patience=70,
    degrees=8.0,
    translate=0.15,
    scale=0.2,
    shear=1.0,
    fliplr=0.5,
    mosaic=0.5,
    mixup=0.5,
    copy_paste=0.0)
# Out:
# New https://pypi.org/project/ultralytics/8.3.246 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics 8.3.242 🚀 Python-3.10.19 torch-2.9.1+cu128 CUDA:0 (NVIDIA GeForce RTX 3070 Laptop GPU, 7974MiB)
# ...

# %%
from ultralytics import YOLO

# %%
model = YOLO('/home/alan_khang/dev/ultralytics/runs/segment/yolo8s_bdd100k2/weights/best.pt')

# %%
metrics = model.val(data='./datasets/bdd100k/labels_yolo/data.yaml')
# Out:
# Ultralytics 8.3.242 🚀 Python-3.10.19 torch-2.9.1+cu128 CUDA:0 (NVIDIA GeForce RTX 3070 Laptop GPU, 7974MiB)
# YOLOv8s-seg summary (fused): 85 layers, 11,782,696 parameters, 0 gradients, 39.9 GFLOPs
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 4586.3±977.1 MB/s, size: 129.9 KB)
# val: Scanning /media/alan_khang/06b61ea7-5333-4d43-be81-2c80a0946359/dataset_zoo/bdd100k/labels_yolo/valid/labels.cache... 981 images, 19 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 1000/1000 2.1Mit/s 0.0s0s
# val: /media/alan_khang/06b61ea7-5333-4d43-be81-2c80a0946359/dataset_zoo/bdd100k/labels_yolo/valid/images/8114e021-00000000.jpg: 1 duplicate labels removed
# val: /media/alan_khang/06b61ea7-5333-4d43-be81-2c80a0946359/dataset_zoo/bdd100k/labels_yolo/valid/images/898ac5b9-00000000.jpg: 1 duplicate labels removed
# val: /media/alan_khang/06b61ea7-5333-4d43-be81-2c80a0946359/dataset_zoo/bdd100k/labels_yolo/valid/images/904f9a94-00000000.jpg: 2 duplicate labels removed
# ...

# %%
metrics.box.maps
# Out:
# array([    0.41927,      0.2685,     0.56901,     0.39581,     0.38812,   0.0016527,     0.37278,     0.20597])
